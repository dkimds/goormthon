# %% [markdown]
# # 네이버 뉴스 크롤러 만들기 연습
# 아래 코드를 실행해야 이하부분이 돌아갑니다.

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd
from datetime import datetime
import time
import re

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 제출 평가 부분

# %%
def main_crawling(query, start_date, end_date, sort_type, max_page):
    '''
    함수기능
    input args::
        query: 설명
        return:
        아웃풋 형태 설명
    '''
    if query == '':
        query = '데이터 분석'
    if len(start_date) != 10:
        start_date = '2021.01.01'
    if len(end_date) != 10:
        end_date = '2021.12.31'
    if sort_type not in ['0', '1', '2']:
        sort_type = '0'
    if max_page == '':
        max_page = 5


    # 각 기사들의 데이터를 종류별로 나눠담을 리스트를 생성합니다. (추후 DataFrame으로 모을 예정)
    categories = []
    titles = []
    dates = []
    articles = []
    article_urls = []
    press_companies = []

    # 주어진 일자를 쿼리에 맞는 형태로 변경해줍니다.
    start_date = start_date.replace(".", "")
    end_date = end_date.replace(".", "")

    # 지정한 기간 내 원하는 페이지 수만큼의 기사를 크롤링합니다.
    current_call = 1
    last_call = (max_page - 1) * 10 + 1 # max_page이 5일 경우 41에 해당


    while current_call <= last_call:

        print('\n{}번째 기사글부터 크롤링을 시작합니다.'.format(current_call))

        url = "https://search.naver.com/search.naver?where=news&query=" + query \
              + "&sort=" + sort_type \
              + "&nso=so%3Ar%2Cp%3Afrom" + start_date \
              + "to" + end_date \
              + "%2Ca%3A&start=" + str(current_call)

        urls_list = []
        try: # 네이버 뉴스 검색결과 페이지 자체에 접근이 불가능할 경우 에러가 발생할 수 있습니다.
            web = requests.get(url).content
            source = BeautifulSoup(web, 'html.parser')

            for urls in source.find_all('a', {'class' : "info"}):
                if urls["href"].startswith("https://n.news.naver.com"):
                    urls_list.append(urls["href"])
        except:
            print('해당 뉴스 검색 페이지의 네이버 뉴스 링크를 모으는 중 에러가 발생했습니다. : ', url)

        # urls_list : 해당 페이지에 있는 "네이버 뉴스"의 링크 모음(list)
        if urls_list != []:
            for url in urls_list:
                try: # 특정 뉴스 기사글 하나를 크롤링하는 중 에러가 발생할 수 있습니다.ㄴ
                    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
                    web_news = requests.get(url, headers=headers).content
                    source_news = BeautifulSoup(web_news, 'html.parser')
                    # 1) 카테고리 class="media_end_categorize_item"
                    category = source_news.find('em',{'class' : 'media_end_categorize_item'}).get_text()

                    title = source_news.find('h2', {'class' : 'media_end_head_headline'}).get_text()
                    print('Processing article : {}'.format(title))

                    date = source_news.find('span', {'class' : 'media_end_head_info_datestamp_time'}).get_text()

                    article = source_news.find('article', {'id' : 'dic_area'}).get_text()
                    article = article.replace("\n", "")
                    article = article.replace("\'", "")
                    article = article.replace("// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}", "")
                    article = article.replace("동영상 뉴스       ", "")
                    article = article.replace("동영상 뉴스", "")
                    article = article.strip()

                    press_company = source_news.find('em', {'class':'media_end_linked_more_point'}).get_text()

                    categories.append(category)
                    titles.append(title)
                    dates.append(date)
                    articles.append(article)
                    press_companies.append(press_company)
                    article_urls.append(url)

                    time.sleep(1)
                except:
                    print('\n*** {}번부터 {}번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.'.format(current_call, current_call+9))
                    print('*** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : {}'.format(url))

        else:
            pass

        current_call += 10


    article_df = pd.DataFrame({'date':dates,
                               'category':categories,
                               'press':press_companies,
                               'title':titles,
                               'document':articles,
                               'link':article_urls,
                               })

    # article_df.to_csv('result_{}.csv'.format(datetime.now().strftime('%y%m%d_%H%M')), index=False, encoding='utf-8')

    print('\n크롤링이 성공적으로 완료되었습니다!')
    print('\n크롤링 결과를 다음 파일에 저장하였습니다 : {}'.format(datetime.now().strftime('%y%m%d_%H%M')))

    return article_df

# %%
query = input('검색어를 입력해주세요. (ex. 데이터 분석) : ')
start_date = input('검색 시작 날짜를 입력해주세요. (형식 : 2021.01.01) : ')
end_date = input('검색 종료 날짜를 입력해주세요. (형식 : 2021.12.31) : ')
sort_type = input('정렬 타입을 입력해주세요 (관련도순 = 0, 최신순 = 1, 오래된순 = 2) : ')
max_page = input('크롤링을 원하는 전체 페이지 수를 입력해주세요. (ex. 5) : ')

if start_date > end_date:
    print('\n시작 날짜는 종료 날짜보다 이후로 지정하실 수 없습니다. 다시 실행해주세요!')
elif max_page == '':
    max_page = 5
    print('\n원하시는 페이지 수가 입력되지 않았습니다. 5 페이지까지만 크롤링을 진행합니다.')
    main_crawling(query, start_date, end_date, sort_type, max_page)
else:
    max_page = int(max_page)
    scraped_news = main_crawling(query, start_date, end_date, sort_type, max_page)
    scraped_news.to_csv('/content/drive/MyDrive/data/result_{}.csv'.format(datetime.now().strftime('%y%m%d_%H%M')), index=False, encoding='utf-8')
# Out:
# 검색어를 입력해주세요. (ex. 데이터 분석) : 부동산
# 검색 시작 날짜를 입력해주세요. (형식 : 2021.01.01) : 2024.01.05
# 검색 종료 날짜를 입력해주세요. (형식 : 2021.12.31) : 2024.02.05
# 정렬 타입을 입력해주세요 (관련도순 = 0, 최신순 = 1, 오래된순 = 2) : 0
# 크롤링을 원하는 전체 페이지 수를 입력해주세요. (ex. 5) : 50
#
# 1번째 기사글부터 크롤링을 시작합니다.
# Processing article : 집값 4억 '뚝'…부동산 거래 침체에 노도강 직격탄
# Processing article : 한덕수 국무총리 "부동산 PF집중 관리하겠다"
# Processing article : "올해 하반기 사이클 최저…부동산 투자 늘려라"
# Processing article : 2024 대구 부동산 전망…올해 2만가구 입주 소화될까?
# Processing article : “車 할부금융 카드사에 뺏겨”… 중소캐피탈이 부동산 PF에 손댄 이유
# Processing article : 中인민은행 등, 부동산 침체 속 임대주택 시장 금융지원 약속
# Processing article : 부동산통계조작 혐의 전 차관 등 영장기각, 검찰 "납득불가"
# Processing article : “이정도면 아이 낳겠습니까?” 5억 파격 대출에 7만 가구 특공 나온다 [부동산360]
# Processing article : [단독] 명지학원 폐교위기 탈출…"부동산 등 매각 1700억 채무 변제"
# Processing article : ‘부동산 PF발 위기’ 건설사 옥석 가리기 본격화…“재개발 사업 리스크는 제한적”
#
# 11번째 기사글부터 크롤링을 시작합니다.
# Processing article : 증권사, 부동산 PF 위기에도 실적 선방으로 극복?
# Processing article : 2024 대구 부동산 전망…올해 2만가구 입주 소화될까?
# Processing article : “車 할부금융 카드사에 뺏겨”… 중소캐피탈이 부동산 PF에 손댄 이유
# Processing article : 장혜영 "정부, 부동산 PF는 지원하고 전세사기 선구제는 외면"
# Processing article : 최상목 "태영건설, 부동산PF에 의존한 예외 케이스…영향 제한"
# Processing article : '부동산 통계 조작 의혹' 관련 윤성원 전 차관 등 영장심사
# Processing article : 새해 부동산 신중한 접근 필요
# Processing article : 中인민은행 등, 부동산 침체 속 임대주택 시장 금융지원 약속
# Processing article : 신축 아파트에 인분·욕설…"사전점검 갔다가 경악"
# Processing article : 네이버페이, '주택담보대출 갈아타기' 출시…"부동산 정보 토털 서비스"
#
# 21번째 기사글부터 크롤링을 시작합니다.
# Processing article : 작년 부동산 냉각 속 전국 아파트 매입 큰 손은 ‘30대’
# Processing article : 전세사기 피해자와 위기 건설사를 대하는 정부의 이중태도[올앳부동산]
# Processing article : [기자수첩]부동산PF 위기…금융회사는 책임 없나
# Processing article : 태성HS, 부동산 불황 속에도 홈쇼핑 분양방송 웃는 이유는?
# Processing article : 부실 뇌관 비주택 PF...15~20조 언제든 터질수 있다[부동산 아토즈]
# Processing article : KDI “부동산 PF 위기에 주택공급 제약될 것…내수 부진 여전”
# Processing article : 민주당, 부동산 PF 위기에 "정부 무능이 초래…옥석 가리기 시급"
# Processing article : PF에 발목잡힌 중소형 증권사…부동산 경기 악화 직격탄
# Processing article : '완주 전세사기' 강제수사…경찰, 부동산 법인 등 압수수색
#
# 31번째 기사글부터 크롤링을 시작합니다.
# Processing article : 최상목 "금투세 폐지, 부자 감세 아냐… 태영건설 부동산PF 영향도 제한적"
# Processing article : 부동산 전문기업 "지난해 전국 임차권 등기명령 269% 급증"
# Processing article : "구조조정 미루면 좌시안할 것"…부동산PF `속도전` 주문한 이복현
# Processing article : 네이버페이, 주담대 갈아타기·새로받기 출시…부동산 서비스와 연계
# Processing article : 금융당국, 오늘 금융지주 소집...부동산 PF 점검
# Processing article : 태영發 부동산PF 리스크 2금융까지 확산 '전운'
# Processing article : 올해 부동산 제도 어떻게 달라지나 [부동산쩐람회]
# Processing article : 중국 ‘그림자 금융’ 상징 중즈그룹 파산…부동산 시장 타격
#
# 41번째 기사글부터 크롤링을 시작합니다.
# 해당 뉴스 검색 페이지의 네이버 뉴스 링크를 모으는 중 에러가 발생했습니다. :  https://search.naver.com/search.naver?where=news&query=부동산&sort=0&nso=so%3Ar%2Cp%3Afrom20240105to20240205%2Ca%3A&start=41
#
# 51번째 기사글부터 크롤링을 시작합니다.
# Processing article : 5억 빚도 겁없이 냈었는데…2030 ‘영끌족’ 두손 두발 다 들었다 [부동산360]
# Processing article : 제2금융권, ‘부동산PF’ 리스크 확산…“올해 건전성 관리 강화” 안간힘
# Processing article : [이코노미 플러스]신생아 가구에 특공·대출 지원 … 올해 바뀌는 부동산 제도는?
# Processing article : 대구 부동산 전문가 10명 중 8명 "2024년 부동산시장 경기 부정적"
# Processing article : "전셋값 10억 낮춰 갱신했어요"…혼돈의 부동산시장
# Processing article : 해외부동산 펀드 80% 손실…당국은 ‘뒷북’
# Processing article : 지난해 부동산 시장 상고하저...올해 집값 전망은?
#
# 61번째 기사글부터 크롤링을 시작합니다.
# Processing article : 부동산PF 부실 규모 최대 70조… “사업성 높이고 부실업장 정리해야”
#
# *** 61번부터 70번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/421/0007278801?sid=106
# Processing article : 인구감소지역에 세컨드홈, '소멸 위기+부동산 침체' 두마리 토끼 잡을까
# Processing article : 지난해 말 부동산 시장 급랭 … 강원 아파트 입주율 50%대 추락 '전국 최저'
# Processing article : 광주시, 부동산 실거래 위반 25건 적발
# Processing article : 건설사 'PF 공포' 확산…롯데·동부건설 "우린 아냐" 적극 해명
# Processing article : 10억원대 성수 아파트, 4개월 새 집값 '와르르'…무슨 일이?
#
# 71번째 기사글부터 크롤링을 시작합니다.
# Processing article : 민생경제 살얼음판…부동산PF 연착륙 '관건'[신년특집-韓경제 향방은③]
# Processing article : 대전서구, 부동산 안심계약 매뉴얼 제작 배포
# Processing article : 캐피탈사, 연체율 급등·부동산PF 위기까지…저축은행사태 데자뷔
# Processing article : 中 부동산 위기에 '그림자 금융' 곡소리…중즈그룹 파산
# Processing article : 부동산 PF 위기에도…올 첫 증권채 수요예측 '완판' [시그널]
# Processing article : 중즈그룹 파산, 中부동산 새로운 불씨 “올해 만기인 부동산 채권 규모 증가”
# Processing article : 민주당, 부동산PF 유동성 위기와 건설사 줄도산 위험 대응 토론회
#
# 81번째 기사글부터 크롤링을 시작합니다.
# Processing article : [기업] 전문건설협회 "부동산 PF 위기 해결할 수 있을 것"
# Processing article : 금융권 부동산PF 대출만 134兆…저축은행 위기감 고조
#
# *** 81번부터 90번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/213/0001282721?sid=106
# Processing article : 감사원발 ‘부동산 통계조작 의혹’…전 국토부 차관 등 2명 영장 심사
# Processing article : 최상목 "태영건설 공적자금 투입 없다...부동산PF에 의존한 예외 케이스"
#
# *** 81번부터 90번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/009/0005242227?sid=106
# Processing article : SH공사, '기존주택 매입해 임대주택 공급' 재개…"집값 하락에 적기"
# Processing article : 지역부동산 부양 승부수 ‘세컨드 홈’, 효과는 어떨까
#
# 91번째 기사글부터 크롤링을 시작합니다.
# Processing article : 노원구 내리면 부동산은 '끝'?…2차 하락기 맞나요[송승현의 손바닥부동산]
# Processing article : 美민주당 "중국, 트럼프 소유 부동산 임대료로 72억원 지급"
# Processing article : 태영건설發 부동산 PF 위기 확산…2금융권 괜찮을까
# Processing article : "中부동산 침체에 베이징·상하이 등 '1선도시' 임대료 하락세"
#
# 101번째 기사글부터 크롤링을 시작합니다.
# Processing article : 네이버페이, 주담대 갈아타기·새로받기 출시…부동산 서비스와 연계
# Processing article : 野 홍익표 "태영건설은 시작…올해는 부동산 PF 구조조정의 해"
# Processing article : 금융당국, 오늘 금융지주 소집...부동산 PF 점검
# Processing article : 제2뇌관 떠오른 '비주택 PF'… 잠재부실 브릿지론만 20兆 [부동산 아토즈]
# Processing article : 태영發 부동산PF 리스크 2금융까지 확산 '전운'
# Processing article : 광주시, 부동산 실거래 위반 25건 적발
# Processing article : 전북 경찰 '완주 전세사기' 부동산 법인 등 압수수색
#
# 111번째 기사글부터 크롤링을 시작합니다.
# Processing article : 전북 경찰 '완주 전세사기' 부동산 법인 등 압수수색
# Processing article : 올해 부동산 제도 어떻게 달라지나 [부동산쩐람회]
# Processing article : 중국 ‘그림자 금융’ 상징 중즈그룹 파산…부동산 시장 타격
# Processing article : 전셋값은 곧 오를 거다, 무주택자 ‘이 지역’ 살펴라 [2024 대전망 ④부동산]
#
# 121번째 기사글부터 크롤링을 시작합니다.
# Processing article : 중국 ‘그림자 금융’ 상징 중즈그룹 파산…부동산 시장 타격
# Processing article : 전셋값은 곧 오를 거다, 무주택자 ‘이 지역’ 살펴라 [2024 대전망 ④부동산]
# Processing article : TY홀딩스 “매각대금 890억 태영건설에 투입…워크아웃 도와달라” [부동산360]
# Processing article : 레디포스트, "부동산 '전자총회 시대' 가속화 전망"
# Processing article : 최상목 "부동산 PF, 단순 유동성 아닌 신용위기…구조조정 이뤄져야"
# Processing article : 네이버페이, 주담대 비교 출시…"부동산 콘텐츠 연계가 차별점"
#
# 131번째 기사글부터 크롤링을 시작합니다.
# Processing article : 네이버페이, 주담대 비교 출시…"부동산 콘텐츠 연계가 차별점"
# Processing article : 1주일 임대에 1억인데 내년까지 예약 꽉차… 성수동 부동산의 비밀
# Processing article : 마스턴운용, 글로벌 상업용 부동산 투자환경 조망 보고서 발간
#
# 141번째 기사글부터 크롤링을 시작합니다.
# Processing article : 부동산 PF발 위기 재발 방지 모범 답안은?
# Processing article : 5억 빚도 겁없이 냈었는데…2030 ‘영끌족’ 두손 두발 다 들었다 [부동산360]
# Processing article : 제2금융권, ‘부동산PF’ 리스크 확산…“올해 건전성 관리 강화” 안간힘
# Processing article : [이코노미 플러스]신생아 가구에 특공·대출 지원 … 올해 바뀌는 부동산 제도는?
# Processing article : 대구 부동산 전문가 10명 중 8명 "2024년 부동산시장 경기 부정적"
#
# 151번째 기사글부터 크롤링을 시작합니다.
# Processing article : 대구 부동산 전문가 10명 중 8명 "2024년 부동산시장 경기 부정적"
# Processing article : 완주 삼례 아파트 전세사기 의혹, 부동산 법인 압수수색
# Processing article : "전셋값 10억 낮춰 갱신했어요"…혼돈의 부동산시장
# Processing article : 해외부동산 펀드 80% 손실…당국은 ‘뒷북’
# Processing article : 지난해 부동산 시장 상고하저...올해 집값 전망은?
#
# 161번째 기사글부터 크롤링을 시작합니다.
# Processing article : 지난해 부동산 시장 상고하저...올해 집값 전망은?
# Processing article : 대구 부동산 전문가 10명 중 4명 "올 하반기 내 집 마련 적기"
# Processing article : 부동산R114-핀다, 주택담보대출 및 거래중개 활성화 협약
# Processing article : 경찰, ‘삼례 전세사기’ 해당 부동산 등 압수수색
# Processing article : 부동산PF 부실 규모 최대 70조… “사업성 높이고 부실업장 정리해야”
# Processing article : 광주시, 부동산 실거래 위반 25건 적발
#
# *** 161번부터 170번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/421/0007278801?sid=106
# Processing article : 인구감소지역에 세컨드홈, '소멸 위기+부동산 침체' 두마리 토끼 잡을까
# Processing article : 지난해 말 부동산 시장 급랭 … 강원 아파트 입주율 50%대 추락 '전국 최저'
#
# 171번째 기사글부터 크롤링을 시작합니다.
# Processing article : 인구감소지역에 세컨드홈, '소멸 위기+부동산 침체' 두마리 토끼 잡을까
# Processing article : 지난해 말 부동산 시장 급랭 … 강원 아파트 입주율 50%대 추락 '전국 최저'
# Processing article : 광주시, 부동산 실거래 위반 25건 적발
# Processing article : 건설사 'PF 공포' 확산…롯데·동부건설 "우린 아냐" 적극 해명
#
# 181번째 기사글부터 크롤링을 시작합니다.
# Processing article : 부동산R114 빅데이터-핀다 대출비교 서비스 결합
# Processing article : 10억원대 성수 아파트, 4개월 새 집값 '와르르'…무슨 일이?
# Processing article : 민생경제 살얼음판…부동산PF 연착륙 '관건'[신년특집-韓경제 향방은③]
# Processing article : 대전서구, 부동산 안심계약 매뉴얼 제작 배포
# Processing article : 文 정부 시절 '부동산 통계 조작 의혹' 윤성원·이문기 대전서 영장실질심사
#
# 191번째 기사글부터 크롤링을 시작합니다.
# Processing article : 캐피탈사, 연체율 급등·부동산PF 위기까지…저축은행사태 데자뷔
# Processing article : 中 부동산 위기에 '그림자 금융' 곡소리…중즈그룹 파산
# Processing article : 경찰, '완주 전세 사기' 강제 수사… 부동산 등 압수수색
#
# 201번째 기사글부터 크롤링을 시작합니다.
# Processing article : 최상목 “태영건설, 부동산PF에 의존한 예외 케이스…영향 제한”
# Processing article : 부동산 PF 위기에도…올 첫 증권채 수요예측 '완판' [시그널]
# Processing article : 중즈그룹 파산, 中부동산 새로운 불씨 “올해 만기인 부동산 채권 규모 증가”
# Processing article : 민주당, 부동산PF 유동성 위기와 건설사 줄도산 위험 대응 토론회
#
# 211번째 기사글부터 크롤링을 시작합니다.
# Processing article : 민주당, 부동산PF 유동성 위기와 건설사 줄도산 위험 대응 토론회
# Processing article : [기업] 전문건설협회 "부동산 PF 위기 해결할 수 있을 것"
# Processing article : 금융권 부동산PF 대출만 134兆…저축은행 위기감 고조
#
# 221번째 기사글부터 크롤링을 시작합니다.
#
# *** 221번부터 230번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/213/0001282721?sid=106
# Processing article : 감사원발 ‘부동산 통계조작 의혹’…전 국토부 차관 등 2명 영장 심사
# Processing article : 최상목 "태영건설 공적자금 투입 없다...부동산PF에 의존한 예외 케이스"
# Processing article : 광주시, 부동산 실거래 신고 위반 25건 적발
#
# 231번째 기사글부터 크롤링을 시작합니다.
#
# *** 231번부터 240번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/009/0005242227?sid=106
# Processing article : 광주 부동산 실거래 신고 위반 25건 적발…“행정처분·국세청 통보”
# Processing article : SH공사, '기존주택 매입해 임대주택 공급' 재개…"집값 하락에 적기"
# Processing article : 지역부동산 부양 승부수 ‘세컨드 홈’, 효과는 어떨까
# Processing article : 노원구 내리면 부동산은 '끝'?…2차 하락기 맞나요[송승현의 손바닥부동산]
#
# 241번째 기사글부터 크롤링을 시작합니다.
# Processing article : 노원구 내리면 부동산은 '끝'?…2차 하락기 맞나요[송승현의 손바닥부동산]
# Processing article : 美민주당 "중국, 트럼프 소유 부동산 임대료로 72억원 지급"
# Processing article : 태영건설發 부동산 PF 위기 확산…2금융권 괜찮을까
#
# 251번째 기사글부터 크롤링을 시작합니다.
# Processing article : F4 회동 이어 부동산 PF 점검…태영 '경우의 수' 논의
# Processing article : 마스턴투자운용 "올 하반기 글로벌 부동산 시장 저점 통과한다"
#
# *** 251번부터 260번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/311/0001679668?sid=106
# Processing article : "中부동산 침체에 베이징·상하이 등 '1선도시' 임대료 하락세"
# Processing article : 부동산PF 유동성 위기와 건설사 줄도산 위험, 어떻게 대응할 것인가? 토론회
# Processing article : 부동산도 ‘이효리 효과’ 상상 이상…단독주택 거래량 전국 1등은 이 동네
# Processing article : 경기도, 땅값＞땅+주택값 '가격역전현상' 지난해 2115호 정비
#
# 261번째 기사글부터 크롤링을 시작합니다.
# Processing article : 부동산PF 유동성 위기와 건설사 줄도산 위험, 어떻게 대응할 것인가? 토론회
# Processing article : [르포]가뜩이나 불경기인데 부동산PF 부실까지..건설 인력시장 '꽁꽁'
# Processing article : 주택보급률 떨어지는데 픽픽 쓰러지는 건설업체… 부동산 시계 ‘제로’[황재성의 황금알]
# Processing article : [빚으로 지은 집]①붕괴하는 '거대한 카르텔'‥韓 부동산 PF 민낯
#
# 271번째 기사글부터 크롤링을 시작합니다.
# Processing article : 올해 정비사업 분양예정 물량 14만가구… 2000년 이후 최다
# Processing article : [빚으로 지은 집]①붕괴하는 '거대한 카르텔'‥韓 부동산 PF 민낯
# Processing article : "분양받은 아파트 건설사 부도나면…우리집은?" [솜소미 부동산]
#
# *** 271번부터 280번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/117/0003799695?sid=106
#
# 281번째 기사글부터 크롤링을 시작합니다.
#
# *** 281번부터 290번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/117/0003799695?sid=106
# Processing article : 고삐 조인 새마을금고…부동산 자금 조달 '적색등'
# Processing article : [데스크 칼럼] 부동산 영끌의 역습
# Processing article : 알스퀘어, '애널리틱스' 론칭…부동산 데이터 접근성 높인다
# Processing article : “금리 아껴주는 은행이 내 편이지”…네카토도 ‘주담대 갈아타기’ 참전
#
# 291번째 기사글부터 크롤링을 시작합니다.
# Processing article : “금리 아껴주는 은행이 내 편이지”…네카토도 ‘주담대 갈아타기’ 참전
# Processing article : "여보, 양양에 '세컨하우스' 사자"…강원도에 부동산 훈풍 불까
# Processing article : 서울 양천구, 부동산 중개보조원에 “명찰 다세요”…전세사기 막는다
# Processing article : 우대빵부동산, 오는 24일 '내 집 마련 콘서트' 개최
# Processing article : 부동산PF ‘옥석’ 가린다는데… 결국 현장별 ‘사업성’ 여부가 관건
# Processing article : [금통위poll]③전문가들 "태영건설 사태, 금융권 영향 제한적"
#
# 301번째 기사글부터 크롤링을 시작합니다.
# Processing article : [금통위poll]③전문가들 "태영건설 사태, 금융권 영향 제한적"
# Processing article : 美·中도 부동산 위기 직면…"정상화까지 수년 소요"
# Processing article : 이복현 "태영 둘러싼 불신, 오너일가가 노력해야 풀 수 있어"
# Processing article : 윤세영 회장 “티와이홀딩스, SBS 주식 담보로 해서 태영건설 꼭 살릴 것”
#
# *** 301번부터 310번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/108/0003207460?sid=106
# Processing article : 올 전국 재건축·재개발 분양 물량 쏟아진다…강남은 2만가구 예정
#
# 311번째 기사글부터 크롤링을 시작합니다.
# Processing article : 올 전국 재건축·재개발 분양 물량 쏟아진다…강남은 2만가구 예정
# Processing article : 태영 워크아웃 무산은 결국 혈세 투입…HUG 치명타입는다 [부동산360]
# Processing article : 부동산 거래절벽에…공인중개사무소 폐업 4년 내 최다
# Processing article : [이슈 인터뷰]"부동산 PF 부실 위기…올핸 구조조정 제대로 추진해야"
# Processing article : [하우머니] 2024 부동산 미리보기…'내 집 마련' 적기는 언제?
#
# 321번째 기사글부터 크롤링을 시작합니다.
# Processing article : 여야 '금투세 폐지' 충돌…"투자자 고려" vs "총선용 정책"
# Processing article : 윤세영 "TY홀딩스·SBS 주식담보로 해서라도 태영건설 꼭 살릴것"
# Processing article : 태영건설 워크아웃 '가닥'…이복현 "채권단 지원 폭넓게 고려"
# Processing article : 가족 간 저가로 부동산양도하는 경우 유의해야 할 사항[도와줘요 부동산세금]
# Processing article : 경기도, 땅값이 땅+주택보다 비싼 '가격역전현상'...2115가구 정비
#
# 331번째 기사글부터 크롤링을 시작합니다.
# Processing article : ‘세컨드 별장’ 사도 1주택...3주택부터 다주택, 농촌 소멸 돌파구 되나 [부동산 아토즈]
# Processing article : 부동산 정책에 불만 많던 중개업자… ‘생활고’가 이재명 피습으로 폭발했나
# Processing article : SH공사, 소형아파트·신축빌라 등 기존주택 사서 서민 임대
# Processing article : 한신평 "중소 증권사 부동산 PF 우려↑…신용도 전망 부정적"
# Processing article : 올해 재건축·재개발 분양물량 14만7천가구…2000년 이후 최다
#
# 341번째 기사글부터 크롤링을 시작합니다.
# Processing article : 서울 아파트 낙찰가율 80.1%…두 달 연속 내림세
# Processing article : 새해에도 여전히 찬바람 ‘오피스텔’, 마피 수두룩…유일한 희망 ‘주택 수 제외’ [감평사의 부동산 현장진단]
# Processing article : 혼돈의 부동산 시장, '매매가 하락세·전세가 상승세'
# Processing article : 부동산 시장 '큰손' 30·40대.. 매매 비중 1년새 또 늘었다
# Processing article : 태영 “SBS 담보도 각오”…사실상 항복선언에 워크아웃 청신호
# Processing article : 부동산 한파에 예금 매력도 떨어져…올 벌써 20조 '머니무브'
# Processing article : 올해 재개발·재건축 14만7185가구…2000년 이후 최다
#
# 351번째 기사글부터 크롤링을 시작합니다.
# Processing article : '통계 조작 의혹' 전 국토부 차관 등 2명 구속영장 기각
# Processing article : 용산에 내집마련 꿈 날벼락…부동산도 몰랐던 물딱지의 함정 [부동산360]
# Processing article : [fn사설] 태영 워크아웃 개시로 부동산 공멸 막아야
# Processing article : "트럼프, 재임 기간 부동산으로 中정부 등서 100억원 받아"
# Processing article : 동업자 통화하는 사이 5억 들고 도주 50대 男 구속송치
#
# *** 351번부터 360번까지의 기사글을 크롤링하는 중 문제가 발생했습니다.
# *** 다음 링크의 뉴스를 크롤링하는 중 에러가 발생했습니다 : https://n.news.naver.com/mnews/article/609/0000810642?sid=106
#
# 361번째 기사글부터 크롤링을 시작합니다.
# Processing article : 전국 주택 입주율, 전월比 5%p ‘뚝’… “PF 악재에 거래절벽 심화”
# Processing article : 대만전문가 "中압박 역효과…부동산 문제 등에 2030표심이 변수"
# Processing article : 민주 이개호 "태영건설 사태, 윤석열 정부의 무능함이 원인"
# Processing article : [머니S포토] 한덕수 총리 "부동산 PF 리스크 집중 관리할 것"
# Processing article : 태영 워크아웃 무산위기 이 난리에…삼성동 평당 3억 사옥 팔릴까? [부동산360]
#
# 371번째 기사글부터 크롤링을 시작합니다.
# Processing article : 中 '그림자 금융'의 상징 파산…부동산發 위기 확산 하나
# Processing article : "부동산PF 최대 70조 부실 우려…부실사업장 정리 필요"
# Processing article : "그들이 사는 세상"…반포동 대장 '원베일리' 맥주까지 나왔다
# Processing article : "부동산PF 130조원 중 최대 70조원 부실 가능성"[집슐랭]
# Processing article : 혼돈의 부동산 시장, '매매가 하락세·전세가 상승세'
# Processing article : "필요하다면 TY홀딩스 · SBS 주식 담보로 제공"
#
# 381번째 기사글부터 크롤링을 시작합니다.
# Processing article : [자막뉴스] 혼돈에 빠진 부동산 시장...전문가가 예상하는 2024년 부동산
# Processing article : 민주, 태영발 PF 위기에 "정부 무능이 초래…옥석가리기 시급"
# Processing article : 이재명 피습 60대 변명문엔 전 정권 부동산·대북외교 비판
# Processing article : 혼돈의 부동산 시장, '매매가 하락세·전세가 상승세'
# Processing article : [2024 신년특집] 올해 부동산 키워드 '상중하저'…빅데이터로 보는 시장 전망은?
# Processing article : 올해도 아파트 하락추세 전망…'내집마련' 언제해야 될까요?[부동산백서]
#
# 391번째 기사글부터 크롤링을 시작합니다.
# Processing article : 한신평 "중소 증권사 부동산 PF 우려↑…신용도 전망 부정적"
# Processing article : 금투협, 국내 부동산 개발·금융 실무 과정 개설
# Processing article : 올해 울산 재건축·재개발 분양 예정 2033가구
# Processing article : 증권업계, PF 여파에 4분기 '실적 한파'…작년 '1조클럽' 없을듯
# Processing article : '통계조작 의혹' 전 국토부 차관 등 2명 영장 기각
# Processing article : 리딩플러스, 부동산 담보평가 시스템 구축…“주소만 입력하면 대출한도 즉시 확인”
#
# 401번째 기사글부터 크롤링을 시작합니다.
# Processing article : '이재명 공격' 피의자 "文정부 부동산 폭망, 대북 굴욕외교로 경제 쑥대밭"
# Processing article : '풍전등화' 건설 업계,  총선 이후 부도 쓰나미 오나
# Processing article : 태영發 후폭풍 덮친다…은행권 충당금 추가적립 비상
# Processing article : "미분양주택 10만 넘어가면 취득세·양도세 감면해야"
# Processing article : 홍콩, 부동산 침체에 1분기 토지판매 안하기로…"13년만에 처음"
# Processing article : '매매가 하락세·전세가 상승세' 보이는 혼돈의 부동산 시장
#
# 411번째 기사글부터 크롤링을 시작합니다.
# Processing article : 中인민은행, 부동산·인프라 64조원 추가 투입…"규모 커질수도"
# Processing article : '두 번째 집' 이곳에 사면 1주택자 간주…파격 대책 나왔다
# Processing article : 부동산 PF 불안 속... 새해 첫 기준금리 ‘8연속 동결’ 유력
# Processing article : “30대가 무슨 돈이 있어서?”…아파트 매입 큰손 된 비결은 ‘이것’
#
# 421번째 기사글부터 크롤링을 시작합니다.
# Processing article : "부동산PF로 중소 증권사 손실 가능성"…한신평, 다올·SK증권 '모니터링'
# Processing article : 올해 재개발·재건축 분양물량, 2000년 이후 최다
# Processing article : 한신공영, 양주 공동주택 개발사업 750억 원 PF 조달
# Processing article : 핀크, '주택담보대출 알아보기' 개시
# Processing article : 증권사 작년 ‘1조클럽’ 실종…‘PF 직격탄’ 4분기 영업익, 전분기比 40% ‘뚝’ [투자360]
# Processing article : 부동산 PF 유동성 우려에… 캐피탈사 신용등급 줄하락
# Processing article : 이재명 습격범 "부동산 폭망 경제파탄에도 이재명 살리기만 올인"
#
# 431번째 기사글부터 크롤링을 시작합니다.
# Processing article : 이재명 습격범 "부동산 폭망 경제파탄에도 이재명 살리기만 올인"
# Processing article : 네이버페이 '주담대 갈아타기' 초읽기..."부동산 서비스 연계해 차별화"
# Processing article : 올해 재건축·재개발 분양예정 14만7천가구…2000년 이후 최다
# Processing article : [단독]동업자 돈 5억 훔쳐 백화점서 쇼핑하던 50대 남성 구속송치
# Processing article : 금감원장 “회생 의지 확인될 경우 폭 넓은 지원 고려해야”
# Processing article : "美대선 앞 인플레 부활 우려 … 中부동산發 금융위기도 변수"
# Processing article : 위기설 차단 나선 롯데·신세계 "부동산 PF 문제없다"
#
# 441번째 기사글부터 크롤링을 시작합니다.
# Processing article : '통계조작 의혹' 前 국토부 차관 등 2명 구속기로…수사 향배는
# Processing article : [주간부동산시황] 수도권 아파트값, 마이너스로 전환…매매수요 위축
# Processing article : [부동산캘린더] 내주 전국 12개 단지서 5천483가구 분양
# Processing article : 부동산 벤처, 2024년 생존이 우선인 이유 [더 머니이스트-심형석의 부동산정석]
# Processing article : ‘文정부 통계조작 의혹’…法, 윤성원·이문기 구속영장 기각
# Processing article : 문턱 높아진 부동산 PF대출 "자기자본 20~40% 투입해야"
# Processing article : 태영건설 흔들리고 부동산 얼어붙자 건설株 '뚝'…증권가는 "옥석 찾아라"
# Processing article : 금융당국, 내일 금융지주 소집...부동산 PF 점검
#
# 451번째 기사글부터 크롤링을 시작합니다.
# Processing article : 中 ‘그림자 금융’ 중즈그룹, 이례적 신속 파산… “금융 리스크 확산 차단”
# Processing article : 서울 아파트 경매시장서도 꺾여…낙찰가율 두달 연속 하락
# Processing article : 11일 채권단협의 앞두고…"알짜 계열사 활용" 카드 꺼낸 태영 [태영건설 추가 자구안]
# Processing article : 당첨되면 ‘3억 로또’…한강변 고양 덕은지구 ‘줍줍 4가구’ 나온다
# Processing article : 작년 전국 아파트 매입 비중, 30대가 40대 추월
# Processing article : 대구시, 부동산 중개 위반 행위 9건 적발
# Processing article : 현대해상, 선제적 리스크관리  주효했나?… 부동산 대출 5대 손보사 중 가장 낮아
# Processing article : "LTV 정보 은밀히 교환" 공정위, 4대 은행 '짬짜미' 제재 착수
#
# 461번째 기사글부터 크롤링을 시작합니다.
# Processing article : “중국 올해 성장률 3~3.5%…부동산 투자 회복 어려울 것”
# Processing article : 2024년 대구 부동산 경기 전망 '암울'…2025년 반등 예상
# Processing article : "미분양 문제 심화되면 취득세·양도세 감면 등 지원책 필요"
# Processing article : 당첨되면 3억 로또...고양 덕은지구서 줍줍 4가구 나온다.
# Processing article : 올해 정비사업 분양예정 14.7만 가구…2000년 이후 최다
#
# 471번째 기사글부터 크롤링을 시작합니다.
# Processing article : 4억씩 빠진 ‘노도강’…거래 절벽에 매물 쌓인다
# Processing article : 서울 아파트 낙찰가율 두달째 하락 '경매지표 위축 지속'
# Processing article : "살던 집 안 팔려"…거래절벽에 새 아파트 입주율 추락
# Processing article : 이재명 습격범 "전 정부 부동산 폭망 경제파탄에도 이재명 살리기만 올인"(종합)
# Processing article : 반포 '아크로리버파크' 경매에 27명 참여… 낙찰가 34억원
# Processing article : 이복현 "워크아웃, 자기책임 원칙 엄격히 적용해야"
# Processing article : [부동산PF 딜레마]'부양' 절실한데 가계부채 발목…해법은?
# Processing article : 여주시, 도세 세수 확보에 총력…누락 세원 발굴도 강화
#
# 481번째 기사글부터 크롤링을 시작합니다.
# Processing article : '통계 조작 의혹' 前 국토부 차관 등 2명 영장 기각
# Processing article : [부동산 캘린더]1월 둘째 주 전국 5483채 분양… 본보기집 2곳 문 열어
# Processing article : 올해 재개발·재건축 분양물량… 2000년 이후 최다
# Processing article : 워크아웃 무산 위기 놓인 태영… "SBS 주식 내놓을 수 있다"
# Processing article : "금투세 폐지, 부자 감세 아니다"…AI·초전도체 '들썩' [마켓플러스]
# Processing article : 태영 "필요시 SBS 지분 담보"…금융당국, 지원 약속
# Processing article : “부동산PF 최대 부실 가능 규모 70조원 달해”
# Processing article : SH공사, 구축 아파트 등 매입해 공공임대로 공급한다 [집슐랭]
# Processing article : 트럼프, ‘부동산 고객’ 中 은행 대북제재 무마 의혹
#
# 491번째 기사글부터 크롤링을 시작합니다.
# Processing article : 대구 전세가격 하락폭 전국 최고...돌려받지 못한 사례도 급증
# Processing article : "올해 재건축·재개발 분양 물량, 2000년 이후 최대"
# Processing article : '평당 1억' 반포 아파트 이름 딴 맥주 출시…전용 신용카드도 나오더니
# Processing article : 불안한 경제, 부동산 규제풀고 감세 '올인'…"SOC투자 상반기 쏟아붓는다”
# Processing article : PF 발목 잡힌 증권사들…'1조 클럽' 실종 위기
#
# 크롤링이 성공적으로 완료되었습니다!
#
# 크롤링 결과를 다음 파일에 저장하였습니다 : 240109_1517
